# %%
import pandas as pd
from rake_nltk import Rake
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
pd.set_option('display.max_columns', 100)
df = pd.read_csv('https://query.data.world/s/uikepcpffyo2nhig52xxeevdialfl7')
df.head()
# Out:
#    Unnamed: 0                     Title  Year     Rated     Released  Runtime  \
# 0           1  The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1           2             The Godfather  1972         R  24 Mar 1972  175 min
# 2           3    The Godfather: Part II  1974         R  20 Dec 1974  202 min
# 3           4           The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 4           5              12 Angry Men  1957  APPROVED  01 Apr 1957   96 min
#
#                   Genre              Director  \
# 0          Crime, Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2          Crime, Drama  Francis Ford Coppola
# 3  Action, Crime, Drama     Christopher Nolan
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
# 2  Francis Ford Coppola (screenplay), Mario Puzo ...
# 3  Jonathan Nolan (screenplay), Christopher Nolan...
# 4  Reginald Rose (story), Reginald Rose (screenplay)
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                      Language  Country  \
# 0                                     English      USA
# 1                     English, Italian, Latin      USA
# 2  English, Italian, Spanish, Latin, Sicilian      USA
# 3                           English, Mandarin  USA, UK
# 4                                     English      USA
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
# 1    Won 3 Oscars. Another 23 wins & 27 nominations.
# 2    Won 6 Oscars. Another 10 wins & 20 nominations.
# 3  Won 2 Oscars. Another 151 wins & 153 nominations.
# 4  Nominated for 3 Oscars. Another 16 wins & 8 no...
#
#                                               Poster           Ratings.Source  \
# 0  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 1  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 2  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 3  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 4  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
#
#   Ratings.Value  Metascore  imdbRating  imdbVotes     imdbID   Type  \
# 0        9.3/10       80.0         9.3  1,825,626  tt0111161  movie
# 1        9.2/10      100.0         9.2  1,243,444  tt0068646  movie
# 2        9.0/10       85.0         9.0    856,870  tt0071562  movie
# 3        9.0/10       82.0         9.0  1,802,351  tt0468569  movie
# 4        8.9/10       96.0         8.9    494,215  tt0050083  movie
#
#    tomatoMeter  tomatoImage  tomatoRating  tomatoReviews  tomatoFresh  \
# 0          NaN          NaN           NaN            NaN          NaN
# 1          NaN          NaN           NaN            NaN          NaN
# 2          NaN          NaN           NaN            NaN          NaN
# 3          NaN          NaN           NaN            NaN          NaN
# 4          NaN          NaN           NaN            NaN          NaN
#
#    tomatoRotten  tomatoConsensus  tomatoUserMeter  tomatoUserRating  \
# 0           NaN              NaN              NaN               NaN
# 1           NaN              NaN              NaN               NaN
# 2           NaN              NaN              NaN               NaN
# 3           NaN              NaN              NaN               NaN
# 4           NaN              NaN              NaN               NaN
#
#    tomatoUserReviews                                          tomatoURL  \
# 0                NaN  http://www.rottentomatoes.com/m/shawshank_rede...
# 1                NaN         http://www.rottentomatoes.com/m/godfather/
# 2                NaN  http://www.rottentomatoes.com/m/godfather_part...
# 3                NaN   http://www.rottentomatoes.com/m/the_dark_knight/
# 4                NaN  http://www.rottentomatoes.com/m/1000013-12_ang...
#
#            DVD     BoxOffice                       Production  \
# 0  27 Jan 1998           NaN                Columbia Pictures
# 1  09 Oct 2001           NaN               Paramount Pictures
# 2  24 May 2005           NaN               Paramount Pictures
# 3  09 Dec 2008  $533,316,061  Warner Bros. Pictures/Legendary
# 4  06 Mar 2001           NaN             Criterion Collection
#
#                                              Website  Response
# 0                                                NaN      True
# 1                        http://www.thegodfather.com      True
# 2                       http://www.thegodfather.com/      True
# 3               http://thedarkknight.warnerbros.com/      True
# 4  http://www.criterion.com/films/27871-12-angry-men      True

# %%
df.shape
# Out:
# (250, 38)

# %% [markdown]
# Choose features to be used for recommendations

# %%
df = df[['Title','Genre','Director','Actors','Plot']]
df.head()
# Out:
#                       Title                 Genre              Director  \
# 0  The Shawshank Redemption          Crime, Drama        Frank Darabont
# 1             The Godfather          Crime, Drama  Francis Ford Coppola
# 2    The Godfather: Part II          Crime, Drama  Francis Ford Coppola
# 3           The Dark Knight  Action, Crime, Drama     Christopher Nolan
# 4              12 Angry Men          Crime, Drama          Sidney Lumet
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                                 Plot
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...

# %%
df.shape
# Out:
# (250, 5)

# %% [markdown]
# Transforming the full names of actors and directors in single words so they are considered as unique values.

# %%
# discarding the commas between the actors' full names and getting only the first three names
df['Actors'] = df['Actors'].map(lambda x: x.split(',')[:3])

# putting the genres in a list of words
df['Genre'] = df['Genre'].map(lambda x: x.lower().split(','))

df['Director'] = df['Director'].map(lambda x: x.split(' '))

# merging together first and last name for each actor and director, so it's considered as one word 
# and there is no mix up between people sharing a first name
for index, row in df.iterrows():
    row['Actors'] = [x.lower().replace(' ','') for x in row['Actors']]
    row['Director'] = ''.join(row['Director']).lower()

# %%
for i,row in df.iterrows():
    print(row)
# Out:
# Title                                The Shawshank Redemption
# Genre                                         [crime,  drama]
# Director                                        frankdarabont
# Actors                 [timrobbins, morganfreeman, bobgunton]
# Plot        Two imprisoned men bond over a number of years...
# Name: 0, dtype: object
# Title                                           The Godfather
# Genre                                         [crime,  drama]
# Director                                   francisfordcoppola
# Actors                    [marlonbrando, alpacino, jamescaan]
# Plot        The aging patriarch of an organized crime dyna...
# Name: 1, dtype: object
# Title                                  The Godfather: Part II
# Genre                                         [crime,  drama]
# Director                                   francisfordcoppola
# Actors                  [alpacino, robertduvall, dianekeaton]
# Plot        The early life and career of Vito Corleone in ...
# Name: 2, dtype: object
# Title                                         The Dark Knight
# Genre                                [action,  crime,  drama]
# Director                                     christophernolan
# Actors             [christianbale, heathledger, aaroneckhart]
# Plot        When the menace known as the Joker emerges fro...
# Name: 3, dtype: object
# Title                                            12 Angry Men
# Genre                                         [crime,  drama]
# Director                                          sidneylumet
# Actors                 [martinbalsam, johnfiedler, leej.cobb]
# Plot        A jury holdout attempts to prevent a miscarria...
# Name: 4, dtype: object
# Title                                        Schindler's List
# Genre                           [biography,  drama,  history]
# Director                                      stevenspielberg
# Actors                [liamneeson, benkingsley, ralphfiennes]
# Plot        In German-occupied Poland during World War II,...
# Name: 5, dtype: object
# Title           The Lord of the Rings: The Return of the King
# Genre                           [adventure,  drama,  fantasy]
# Director                                         peterjackson
# Actors                     [noelappleby, aliastin, seanastin]
# Plot        Gandalf and Aragorn lead the World of Men agai...
# Name: 6, dtype: object
# Title                                            Pulp Fiction
# Genre                                         [crime,  drama]
# Director                                     quentintarantino
# Actors                [timroth, amandaplummer, lauralovelace]
# Plot        The lives of two mob hit men, a boxer, a gangs...
# Name: 7, dtype: object
# Title                                              Fight Club
# Genre                                                 [drama]
# Director                                         davidfincher
# Actors                     [edwardnorton, bradpitt, meatloaf]
# Plot        An insomniac office worker, looking for a way ...
# Name: 8, dtype: object
# Title       The Lord of the Rings: The Fellowship of the Ring
# Genre                           [adventure,  drama,  fantasy]
# Director                                         peterjackson
# Actors                   [alanhoward, noelappleby, seanastin]
# Plot        A meek Hobbit from the Shire and eight compani...
# Name: 9, dtype: object
# Title                                            Forrest Gump
# Genre                              [comedy,  drama,  romance]
# Director                                       robertzemeckis
# Actors                [tomhanks, rebeccawilliams, sallyfield]
# Plot        While not intelligent, Forrest Gump has accide...
# Name: 10, dtype: object
# Title          Star Wars: Episode V - The Empire Strikes Back
# Genre                          [action,  adventure,  fantasy]
# Director                                        irvinkershner
# Actors               [markhamill, harrisonford, carriefisher]
# Plot        After the rebels are overpowered by the Empire...
# Name: 11, dtype: object
# Title                                               Inception
# Genre                           [action,  adventure,  sci-fi]
# Director                                     christophernolan
# Actors      [leonardodicaprio, josephgordon-levitt, ellenp...
# Plot        A thief, who steals corporate secrets through ...
# Name: 12, dtype: object
# Title                   The Lord of the Rings: The Two Towers
# Genre                           [adventure,  drama,  fantasy]
# Director                                         peterjackson
# Actors                   [bruceallpress, seanastin, johnbach]
# Plot        While Frodo and Sam edge closer to Mordor with...
# Name: 13, dtype: object
# Title                         One Flew Over the Cuckoo's Nest
# Genre                                                 [drama]
# Director                                          milosforman
# Actors           [michaelberryman, peterbrocco, deanr.brooks]
# Plot        A criminal pleads insanity after getting into ...
# Name: 14, dtype: object
# Title                                              Goodfellas
# Genre                                         [crime,  drama]
# Director                                       martinscorsese
# Actors                    [robertdeniro, rayliotta, joepesci]
# Plot        The story of Henry Hill and his life through t...
# Name: 15, dtype: object
# Title                                              The Matrix
# Genre                                       [action,  sci-fi]
# Director                         lanawachowski,lillywachowski
# Actors      [keanureeves, laurencefishburne, carrie-annemoss]
# Plot        A computer hacker learns from mysterious rebel...
# Name: 16, dtype: object
# Title                      Star Wars: Episode IV - A New Hope
# Genre                          [action,  adventure,  fantasy]
# Director                                          georgelucas
# Actors               [markhamill, harrisonford, carriefisher]
# Plot        Luke Skywalker joins forces with a Jedi Knight...
# Name: 17, dtype: object
# Title                                                   Se7en
# Genre                               [crime,  drama,  mystery]
# Director                                         davidfincher
# Actors        [morganfreeman, andrewkevinwalker, kevinspacey]
# Plot        Two detectives, a rookie and a veteran, hunt a...
# Name: 18, dtype: object
# Title                                   It's a Wonderful Life
# Genre                              [drama,  family,  fantasy]
# Director                                           frankcapra
# Actors             [jamesstewart, donnareed, lionelbarrymore]
# Plot        An angel is sent from Heaven to help a despera...
# Name: 19, dtype: object
# Title                                The Silence of the Lambs
# Genre                              [crime,  drama,  thriller]
# Director                                        jonathandemme
# Actors           [jodiefoster, lawrencea.bonney, kasilemmons]
# Plot        A young F.B.I. cadet must confide in an incarc...
# Name: 20, dtype: object
# Title                                      The Usual Suspects
# Genre                               [crime,  drama,  mystery]
# Director                                          bryansinger
# Actors         [stephenbaldwin, gabrielbyrne, beniciodeltoro]
# Plot        A sole survivor tells of the twisty events lea...
# Name: 21, dtype: object
# Title                                  Léon: The Professional
# Genre                              [crime,  drama,  thriller]
# Director                                            lucbesson
# Actors                 [jeanreno, garyoldman, natalieportman]
# Plot        Mathilda, a 12-year-old girl, is reluctantly t...
# Name: 22, dtype: object
# Title                                     Saving Private Ryan
# Genre                                           [drama,  war]
# Director                                      stevenspielberg
# Actors                   [tomhanks, tomsizemore, edwardburns]
# Plot        Following the Normandy Landings, a group of U....
# Name: 23, dtype: object
# Title                                             City Lights
# Genre                              [comedy,  drama,  romance]
# Director                                       charleschaplin
# Actors            [virginiacherrill, florencelee, harrymyers]
# Plot        With the aid of a wealthy erratic tippler, a d...
# Name: 24, dtype: object
# Title                                            Interstellar
# Genre                            [adventure,  drama,  sci-fi]
# Director                                     christophernolan
# Actors       [ellenburstyn, matthewmcconaughey, mackenziefoy]
# Plot        A team of explorers travel through a wormhole ...
# Name: 25, dtype: object
# Title                                      American History X
# Genre                                         [crime,  drama]
# Director                                             tonykaye
# Actors         [edwardnorton, edwardfurlong, beverlyd'angelo]
# Plot        A former neo-nazi skinhead tries to prevent hi...
# Name: 26, dtype: object
# Title                                            Modern Times
# Genre                               [comedy,  drama,  family]
# Director                                       charleschaplin
# Actors        [charleschaplin, paulettegoddard, henrybergman]
# Plot        The Tramp struggles to live in modern industri...
# Name: 27, dtype: object
# Title                                              Casablanca
# Genre                                 [drama,  romance,  war]
# Director                                        michaelcurtiz
# Actors           [humphreybogart, ingridbergman, paulhenreid]
# Plot        In Casablanca in December 1941, a cynical Amer...
# Name: 28, dtype: object
# Title                                          The Green Mile
# Genre                               [crime,  drama,  fantasy]
# Director                                        frankdarabont
# Actors            [tomhanks, davidmorse, michaelclarkeduncan]
# Plot        The lives of guards on Death Row are affected ...
# Name: 29, dtype: object
# Title                                                  Psycho
# Genre                           [horror,  mystery,  thriller]
# Director                                      alfredhitchcock
# Actors                 [anthonyperkins, veramiles, johngavin]
# Plot        A Phoenix secretary embezzles $40,000 from her...
# Name: 30, dtype: object
# Title                                 Raiders of the Lost Ark
# Genre                                    [action,  adventure]
# Director                                      stevenspielberg
# Actors                [harrisonford, karenallen, paulfreeman]
# Plot        Archaeologist and adventurer Indiana Jones is ...
# Name: 31, dtype: object
# Title                                             The Pianist
# Genre                             [biography,  drama,  music]
# Director                                        romanpolanski
# Actors              [adrienbrody, emiliafox, michalzebrowski]
# Plot        A Polish Jewish musician struggles to survive ...
# Name: 32, dtype: object
# Title                                             Rear Window
# Genre                                    [mystery,  thriller]
# Director                                      alfredhitchcock
# Actors               [jamesstewart, gracekelly, wendellcorey]
# Plot        A wheelchair-bound photographer spies on his n...
# Name: 33, dtype: object
# Title                                            The Departed
# Genre                              [crime,  drama,  thriller]
# Director                                       martinscorsese
# Actors           [leonardodicaprio, mattdamon, jacknicholson]
# Plot        An undercover cop and a mole in the police att...
# Name: 34, dtype: object
# Title                                                Whiplash
# Genre                                         [drama,  music]
# Director                                       damienchazelle
# Actors                 [milesteller, j.k.simmons, paulreiser]
# Plot        A promising young drummer enrolls at a cut-thr...
# Name: 35, dtype: object
# Title                              Terminator 2: Judgment Day
# Genre                            [action,  sci-fi,  thriller]
# Director                                         jamescameron
# Actors      [arnoldschwarzenegger, lindahamilton, edwardfu...
# Plot        A cyborg, identical to the one who failed to k...
# Name: 36, dtype: object
# Title                                      Back to the Future
# Genre                           [adventure,  comedy,  sci-fi]
# Director                                       robertzemeckis
# Actors          [michaelj.fox, christopherlloyd, leathompson]
# Plot        Marty McFly, a 17-year-old high school student...
# Name: 37, dtype: object
# Title                                               Gladiator
# Genre                            [action,  adventure,  drama]
# Director                                          ridleyscott
# Actors          [russellcrowe, joaquinphoenix, connienielsen]
# Plot        When a Roman general is betrayed and his famil...
# Name: 38, dtype: object
# Title                                           The Lion King
# Genre                         [animation,  adventure,  drama]
# Director                               rogerallers,robminkoff
# Actors        [rowanatkinson, matthewbroderick, niketacalame]
# Plot        Lion cub and future king Simba searches for hi...
# Name: 39, dtype: object
# Title                                            The Prestige
# Genre                              [drama,  mystery,  sci-fi]
# Director                                     christophernolan
# Actors             [hughjackman, christianbale, michaelcaine]
# Plot        Two stage magicians engage in competitive one-...
# Name: 40, dtype: object
# Title                                          Apocalypse Now
# Genre                                           [drama,  war]
# Director                                   francisfordcoppola
# Actors              [marlonbrando, martinsheen, robertduvall]
# Plot        During the Vietnam War, Captain Willard is sen...
# Name: 41, dtype: object
# Title                                                 Memento
# Genre                                    [mystery,  thriller]
# Director                                     christophernolan
# Actors            [guypearce, carrie-annemoss, joepantoliano]
# Plot        A man juggles searching for his wife's murdere...
# Name: 42, dtype: object
# Title                                      The Great Dictator
# Genre                                  [comedy,  drama,  war]
# Director                                       charleschaplin
# Actors          [charleschaplin, jackoakie, reginaldgardiner]
# Plot        Dictator Adenoid Hynkel tries to expand his em...
# Name: 43, dtype: object
# Title                                        Sunset Boulevard
# Genre                                     [drama,  film-noir]
# Director                                          billywilder
# Actors       [williamholden, gloriaswanson, erichvonstroheim]
# Plot        A screenwriter is hired to rework a faded sile...
# Name: 44, dtype: object
# Title                                                   Alien
# Genre                                       [horror,  sci-fi]
# Director                                          ridleyscott
# Actors      [tomskerritt, sigourneyweaver, veronicacartwri...
# Plot        After a space merchant vessel perceives an unk...
# Name: 45, dtype: object
# Title       Dr. Strangelove or: How I Learned to Stop Worr...
# Genre                                                [comedy]
# Director                                       stanleykubrick
# Actors          [petersellers, georgec.scott, sterlinghayden]
# Plot        An insane general triggers a path to nuclear h...
# Name: 46, dtype: object
# Title                                          Paths of Glory
# Genre                                           [drama,  war]
# Director                                       stanleykubrick
# Actors              [kirkdouglas, ralphmeeker, adolphemenjou]
# Plot        After refusing to attack an enemy position, a ...
# Name: 47, dtype: object
# Title                                        Django Unchained
# Genre                                       [drama,  western]
# Director                                     quentintarantino
# Actors          [jamiefoxx, christophwaltz, leonardodicaprio]
# Plot        With the help of a German bounty hunter , a fr...
# Name: 48, dtype: object
# Title                                             The Shining
# Genre                                        [drama,  horror]
# Director                                       stanleykubrick
# Actors             [jacknicholson, shelleyduvall, dannylloyd]
# Plot        A family heads to an isolated hotel for the wi...
# Name: 49, dtype: object
# Title                             Witness for the Prosecution
# Genre                               [crime,  drama,  mystery]
# Director                                          billywilder
# Actors        [tyronepower, marlenedietrich, charleslaughton]
# Plot        A veteran British barrister must defend his cl...
# Name: 50, dtype: object
# Title                                   The Dark Knight Rises
# Genre                                     [action,  thriller]
# Director                                     christophernolan
# Actors                  [christianbale, garyoldman, tomhardy]
# Plot        Eight years after the Joker's reign of anarchy...
# Name: 51, dtype: object
# Title                                                  WALL·E
# Genre                        [animation,  adventure,  family]
# Director                                        andrewstanton
# Actors                   [benburtt, elissaknight, jeffgarlin]
# Plot        In the distant future, a small waste-collectin...
# Name: 52, dtype: object
# Title                                         American Beauty
# Genre                                       [drama,  romance]
# Director                                            sammendes
# Actors               [kevinspacey, annettebening, thorabirch]
# Plot        A sexually frustrated suburban father has a mi...
# Name: 53, dtype: object
# Title                             Once Upon a Time in America
# Genre                                         [crime,  drama]
# Director                                          sergioleone
# Actors          [robertdeniro, jameswoods, elizabethmcgovern]
# Plot        A former Prohibition-era Jewish gangster retur...
# Name: 54, dtype: object
# Title                                                  Aliens
# Genre                           [action,  adventure,  sci-fi]
# Director                                         jamescameron
# Actors            [sigourneyweaver, carriehenn, michaelbiehn]
# Plot        The moon from Alien (1979) has been colonized,...
# Name: 55, dtype: object
# Title                                            Citizen Kane
# Genre                                       [drama,  mystery]
# Director                                          orsonwelles
# Actors       [josephcotten, dorothycomingore, agnesmoorehead]
# Plot        Following the death of a publishing tycoon, ne...
# Name: 56, dtype: object
# Title                                      North by Northwest
# Genre                          [action,  adventure,  mystery]
# Director                                      alfredhitchcock
# Actors                 [carygrant, evamariesaint, jamesmason]
# Plot        A hapless New York advertising executive is mi...
# Name: 57, dtype: object
# Title                                                 Vertigo
# Genre                          [mystery,  romance,  thriller]
# Director                                      alfredhitchcock
# Actors             [jamesstewart, kimnovak, barbarabelgeddes]
# Plot        A San Francisco detective suffering from acrop...
# Name: 58, dtype: object
# Title              Star Wars: Episode VI - Return of the Jedi
# Genre                          [action,  adventure,  fantasy]
# Director                                      richardmarquand
# Actors               [markhamill, harrisonford, carriefisher]
# Plot        After a daring mission to rescue Han Solo from...
# Name: 59, dtype: object
# Title                                              Braveheart
# Genre                           [biography,  drama,  history]
# Director                                            melgibson
# Actors               [jamesrobinson, seanlawlor, sandynelson]
# Plot        When his secret bride is executed for assaulti...
# Name: 60, dtype: object
# Title                                          Reservoir Dogs
# Genre                              [crime,  drama,  thriller]
# Director                                     quentintarantino
# Actors                 [harveykeitel, timroth, michaelmadsen]
# Plot        After a simple jewelry heist goes terribly wro...
# Name: 61, dtype: object
# Title                                        Double Indemnity
# Genre                             [crime,  drama,  film-noir]
# Director                                          billywilder
# Actors      [fredmacmurray, barbarastanwyck, edwardg.robin...
# Plot        An insurance representative lets himself be ta...
# Name: 62, dtype: object
# Title                                     Requiem for a Dream
# Genre                                                 [drama]
# Director                                      darrenaronofsky
# Actors            [ellenburstyn, jaredleto, jenniferconnelly]
# Plot        The drug-induced utopias of four Coney Island ...
# Name: 63, dtype: object
# Title                                      Lawrence of Arabia
# Genre                         [adventure,  biography,  drama]
# Director                                            davidlean
# Actors             [petero'toole, alecguinness, anthonyquinn]
# Plot        The story of T.E. Lawrence, the English office...
# Name: 64, dtype: object
# Title                                                 The Kid
# Genre                               [comedy,  drama,  family]
# Director                                       charleschaplin
# Actors              [carlmiller, ednapurviance, jackiecoogan]
# Plot        The Tramp cares for an abandoned child, but ev...
# Name: 65, dtype: object
# Title                                      A Clockwork Orange
# Genre                                [crime,  drama,  sci-fi]
# Director                                       stanleykubrick
# Actors          [malcolmmcdowell, patrickmagee, michaelbates]
# Plot        In future Britain, Alex DeLarge, a charismatic...
# Name: 66, dtype: object
# Title                                                 Amadeus
# Genre                           [biography,  drama,  history]
# Director                                          milosforman
# Actors         [f.murrayabraham, tomhulce, elizabethberridge]
# Plot        The incredible story of Wolfgang Amadeus Mozar...
# Name: 67, dtype: object
# Title                                   To Kill a Mockingbird
# Genre                                         [crime,  drama]
# Director                                       robertmulligan
# Actors                 [gregorypeck, johnmegna, frankoverton]
# Plot        Atticus Finch, a lawyer in the Depression-era ...
# Name: 68, dtype: object
# Title                   Eternal Sunshine of the Spotless Mind
# Genre                              [drama,  romance,  sci-fi]
# Director                                         michelgondry
# Actors             [jimcarrey, katewinslet, gerryrobertbyrne]
# Plot        When their relationship turns sour, a couple u...
# Name: 69, dtype: object
# Title                                     Singin' in the Rain
# Genre                            [comedy,  musical,  romance]
# Director                               stanleydonen,genekelly
# Actors            [genekelly, donaldo'connor, debbiereynolds]
# Plot        A silent film production company and cast make...
# Name: 70, dtype: object
# Title                                             Taxi Driver
# Genre                                         [crime,  drama]
# Director                                       martinscorsese
# Actors                  [diahnneabbott, frankadu, victorargo]
# Plot        A mentally unstable Vietnam War veteran works ...
# Name: 71, dtype: object
# Title                                               The Sting
# Genre                                [comedy,  crime,  drama]
# Director                                        georgeroyhill
# Actors                [paulnewman, robertredford, robertshaw]
# Plot        In Chicago in September 1936, a young con man ...
# Name: 72, dtype: object
# Title                                             Toy Story 3
# Genre                        [animation,  adventure,  comedy]
# Director                                           leeunkrich
# Actors                       [tomhanks, timallen, joancusack]
# Plot        The toys are mistakenly delivered to a day-car...
# Name: 73, dtype: object
# Title                                   2001: A Space Odyssey
# Genre                                    [adventure,  sci-fi]
# Director                                       stanleykubrick
# Actors           [keirdullea, garylockwood, williamsylvester]
# Plot        Humanity finds a mysterious, obviously artific...
# Name: 74, dtype: object
# Title                                       Full Metal Jacket
# Genre                                           [drama,  war]
# Director                                       stanleykubrick
# Actors         [matthewmodine, adambaldwin, vincentd'onofrio]
# Plot        A pragmatic U.S. Marine observes the dehumaniz...
# Name: 75, dtype: object
# Title                                             Baby Driver
# Genre                                [action,  crime,  music]
# Director                                          edgarwright
# Actors                    [anselelgort, jonbernthal, jonhamm]
# Plot        After being coerced into working for a crime b...
# Name: 76, dtype: object
# Title                                               Toy Story
# Genre                        [animation,  adventure,  comedy]
# Director                                         johnlasseter
# Actors                       [tomhanks, timallen, donrickles]
# Plot        A cowboy doll is profoundly threatened and jea...
# Name: 77, dtype: object
# Title                                    Inglourious Basterds
# Genre                               [adventure,  drama,  war]
# Director                             quentintarantino,eliroth
# Actors             [bradpitt, mélanielaurent, christophwaltz]
# Plot        In Nazi-occupied France during World War II, a...
# Name: 78, dtype: object
# Title                                                  Snatch
# Genre                                        [comedy,  crime]
# Director                                           guyritchie
# Actors            [beniciodeltoro, dennisfarina, vinniejones]
# Plot        Unscrupulous boxing promoters, violent bookmak...
# Name: 79, dtype: object
# Title                                           The Apartment
# Genre                              [comedy,  drama,  romance]
# Director                                          billywilder
# Actors           [jacklemmon, shirleymaclaine, fredmacmurray]
# Plot        A man tries to rise in his company by letting ...
# Name: 80, dtype: object
# Title                                           All About Eve
# Genre                                                 [drama]
# Director                                   josephl.mankiewicz
# Actors                [bettedavis, annebaxter, georgesanders]
# Plot        An ingenue insinuates herself into the company...
# Name: 81, dtype: object
# Title                         Monty Python and the Holy Grail
# Genre                          [adventure,  comedy,  fantasy]
# Director                              terrygilliam,terryjones
# Actors                  [grahamchapman, johncleese, ericidle]
# Plot        King Arthur and his knights embark on a low-bu...
# Name: 82, dtype: object
# Title                                                Scarface
# Genre                                         [crime,  drama]
# Director                                         briandepalma
# Actors              [alpacino, stevenbauer, michellepfeiffer]
# Plot        In Miami in 1980, a determined Cuban immigrant...
# Name: 83, dtype: object
# Title                                       L.A. Confidential
# Genre                               [crime,  drama,  mystery]
# Director                                         curtishanson
# Actors                 [kevinspacey, russellcrowe, guypearce]
# Plot        As corruption grows in 1950s LA, three policem...
# Name: 84, dtype: object
# Title                                       Good Will Hunting
# Genre                                                 [drama]
# Director                                           gusvansant
# Actors              [mattdamon, benaffleck, stellanskarsgård]
# Plot        Will Hunting, a janitor at M.I.T., has a gift ...
# Name: 85, dtype: object
# Title                        The Treasure of the Sierra Madre
# Genre                           [adventure,  drama,  western]
# Director                                           johnhuston
# Actors                [humphreybogart, walterhuston, timholt]
# Plot        Fred Dobbs and Bob Curtin, two Americans searc...
# Name: 86, dtype: object
# Title                      Indiana Jones and the Last Crusade
# Genre                          [action,  adventure,  fantasy]
# Director                                      stevenspielberg
# Actors            [harrisonford, seanconnery, denholmelliott]
# Plot        When Dr. Henry Jones Sr. suddenly goes missing...
# Name: 87, dtype: object
# Title                                        Some Like It Hot
# Genre                                      [comedy,  romance]
# Director                                          billywilder
# Actors                [marilynmonroe, tonycurtis, jacklemmon]
# Plot        When two male musicians witness a mob hit, the...
# Name: 88, dtype: object
# Title                                           Batman Begins
# Genre                                    [action,  adventure]
# Director                                     christophernolan
# Actors              [christianbale, michaelcaine, liamneeson]
# Plot        After training with his mentor, Batman begins ...
# Name: 89, dtype: object
# Title                                                      Up
# Genre                        [animation,  adventure,  comedy]
# Director                               petedocter,bobpeterson
# Actors         [edwardasner, christopherplummer, jordannagai]
# Plot        Seventy-eight year old Carl Fredricksen travel...
# Name: 90, dtype: object
# Title                                           The Third Man
# Genre                        [film-noir,  mystery,  thriller]
# Director                                            carolreed
# Actors                [josephcotten, alidavalli, orsonwelles]
# Plot        Pulp novelist Holly Martins travels to shadowy...
# Name: 91, dtype: object
# Title                                              Unforgiven
# Genre                                       [drama,  western]
# Director                                        clinteastwood
# Actors            [clinteastwood, genehackman, morganfreeman]
# Plot        Retired Old West gunslinger William Munny relu...
# Name: 92, dtype: object
# Title                                   Judgment at Nuremberg
# Genre                                           [drama,  war]
# Director                                        stanleykramer
# Actors          [spencertracy, burtlancaster, richardwidmark]
# Plot        In 1948, an American court in occupied Germany...
# Name: 93, dtype: object
# Title                                             Raging Bull
# Genre                             [biography,  drama,  sport]
# Director                                       martinscorsese
# Actors                [robertdeniro, cathymoriarty, joepesci]
# Plot        An emotionally self-destructive boxer's journe...
# Name: 94, dtype: object
# Title                                        The Great Escape
# Genre                           [adventure,  drama,  history]
# Director                                          johnsturges
# Actors       [stevemcqueen, jamesgarner, richardattenborough]
# Plot        Allied prisoners of war plan for several hundr...
# Name: 95, dtype: object
# Title                                                    Heat
# Genre                                [action,  crime,  drama]
# Director                                          michaelmann
# Actors                    [alpacino, robertdeniro, valkilmer]
# Plot        A group of professional bank robbers start to ...
# Name: 96, dtype: object
# Title                                                Die Hard
# Genre                                     [action,  thriller]
# Director                                        johnmctiernan
# Actors       [brucewillis, bonniebedelia, reginaldveljohnson]
# Plot        John McClane, officer of the NYPD, tries to sa...
# Name: 97, dtype: object
# Title                                           The Gold Rush
# Genre                            [adventure,  comedy,  drama]
# Director                                       charleschaplin
# Actors                 [charleschaplin, mackswain, tommurray]
# Plot        A prospector goes to the Klondike in search of...
# Name: 98, dtype: object
# Title                                               Chinatown
# Genre                            [drama,  mystery,  thriller]
# Director                                        romanpolanski
# Actors               [jacknicholson, fayedunaway, johnhuston]
# Plot        A private detective hired to expose an adulter...
# Name: 99, dtype: object
# Title                                       On the Waterfront
# Genre                              [crime,  drama,  thriller]
# Director                                            eliakazan
# Actors                  [marlonbrando, karlmalden, leej.cobb]
# Plot        An ex-prize fighter turned longshoreman strugg...
# Name: 100, dtype: object
# Title                            Mr. Smith Goes to Washington
# Genre                                        [comedy,  drama]
# Director                                           frankcapra
# Actors                [jeanarthur, jamesstewart, clauderains]
# Plot        A naive man is appointed to fill a vacancy in ...
# Name: 101, dtype: object
# Title                                             The General
# Genre                           [action,  adventure,  comedy]
# Director                           clydebruckman,busterkeaton
# Actors               [busterkeaton, marionmack, glencavender]
# Plot        When Union spies steal an engineer's beloved l...
# Name: 102, dtype: object
# Title                                              Inside Out
# Genre                        [animation,  adventure,  comedy]
# Director                           petedocter,ronniedelcarmen
# Actors                [amypoehler, phyllissmith, richardkind]
# Plot        After young Riley is uprooted from her Midwest...
# Name: 103, dtype: object
# Title                            The Bridge on the River Kwai
# Genre                               [adventure,  drama,  war]
# Director                                            davidlean
# Actors             [williamholden, alecguinness, jackhawkins]
# Plot        After settling his differences with a Japanese...
# Name: 104, dtype: object
# Title                                                    Room
# Genre                                                 [drama]
# Director                                      lennyabrahamson
# Actors              [brielarson, jacobtremblay, seanbridgers]
# Plot        A young boy is raised within the confines of a...
# Name: 105, dtype: object
# Title                                              La La Land
# Genre                                [comedy,  drama,  music]
# Director                                       damienchazelle
# Actors                    [ryangosling, emmastone, amiéeconn]
# Plot        A jazz pianist falls for an aspiring actress i...
# Name: 106, dtype: object
# Title                                                   Logan
# Genre                               [action,  drama,  sci-fi]
# Director                                         jamesmangold
# Actors               [hughjackman, patrickstewart, dafnekeen]
# Plot        In the near future, a weary Logan cares for an...
# Name: 107, dtype: object
# Title                                            Blade Runner
# Genre                                     [sci-fi,  thriller]
# Director                                          ridleyscott
# Actors                 [harrisonford, rutgerhauer, seanyoung]
# Plot        A blade runner must pursue and try to terminat...
# Name: 108, dtype: object
# Title                     Lock, Stock and Two Smoking Barrels
# Genre                                        [comedy,  crime]
# Director                                           guyritchie
# Actors              [jasonflemyng, dexterfletcher, nickmoran]
# Plot        A botched card game in London triggers four fr...
# Name: 109, dtype: object
# Title                                                  Casino
# Genre                                         [crime,  drama]
# Director                                       martinscorsese
# Actors                  [robertdeniro, sharonstone, joepesci]
# Plot        Greed, deception, money, power, and murder occ...
# Name: 110, dtype: object
# Title                                        A Beautiful Mind
# Genre                                     [biography,  drama]
# Director                                            ronhoward
# Actors             [russellcrowe, edharris, jenniferconnelly]
# Plot        After John Nash, a brilliant but asocial mathe...
# Name: 111, dtype: object
# Title                                        The Elephant Man
# Genre                                     [biography,  drama]
# Director                                           davidlynch
# Actors               [anthonyhopkins, johnhurt, annebancroft]
# Plot        A Victorian surgeon rescues a heavily disfigur...
# Name: 112, dtype: object
# Title                                                 Warrior
# Genre                                [action,  drama,  sport]
# Director                                        gavino'connor
# Actors                    [joeledgerton, tomhardy, nicknolte]
# Plot        The youngest son of an alcoholic former boxer ...
# Name: 113, dtype: object
# Title                                          V for Vendetta
# Genre                             [action,  drama,  thriller]
# Director                                        jamesmcteigue
# Actors              [natalieportman, hugoweaving, stephenrea]
# Plot        In a future British tyranny, a shadowy freedom...
# Name: 114, dtype: object
# Title                                 The Wolf of Wall Street
# Genre                            [biography,  comedy,  crime]
# Director                                       martinscorsese
# Actors            [leonardodicaprio, jonahhill, margotrobbie]
# Plot        Based on the true story of Jordan Belfort, fro...
# Name: 115, dtype: object
# Title                                       Dial M for Murder
# Genre                          [crime,  film-noir,  thriller]
# Director                                      alfredhitchcock
# Actors               [raymilland, gracekelly, robertcummings]
# Plot        An ex-tennis pro carries out a plot to murder ...
# Name: 116, dtype: object
# Title                                           Hacksaw Ridge
# Genre                           [biography,  drama,  history]
# Director                                            melgibson
# Actors            [andrewgarfield, richardpyros, jacobwarner]
# Plot        WWII American Army Medic Desmond T. Doss, who ...
# Name: 117, dtype: object
# Title                                      Gone with the Wind
# Genre                             [drama,  history,  romance]
# Director                    victorfleming,georgecukor,samwood
# Actors           [thomasmitchell, barbarao'neil, vivienleigh]
# Plot        A manipulative woman and a roguish man conduct...
# Name: 118, dtype: object
# Title                                             The Message
# Genre                         [adventure,  biography,  drama]
# Director                                       moustaphaakkad
# Actors              [anthonyquinn, irenepapas, michaelansara]
# Plot        In the 7th century, Mohammed, Peace Be Upon Hi...
# Name: 119, dtype: object
# Title                                                 Rebecca
# Genre                             [drama,  mystery,  romance]
# Director                                      alfredhitchcock
# Actors         [laurenceolivier, joanfontaine, georgesanders]
# Plot        A self-conscious bride is tormented by the mem...
# Name: 120, dtype: object
# Title                                           Trainspotting
# Genre                                                 [drama]
# Director                                           dannyboyle
# Actors            [ewanmcgregor, ewenbremner, jonnyleemiller]
# Plot        Renton, deeply immersed in the Edinburgh drug ...
# Name: 121, dtype: object
# Title                                         The Deer Hunter
# Genre                                           [drama,  war]
# Director                                        michaelcimino
# Actors                 [robertdeniro, johncazale, johnsavage]
# Plot        An in-depth examination of the ways in which t...
# Name: 122, dtype: object
# Title                                          Cool Hand Luke
# Genre                                         [crime,  drama]
# Director                                      stuartrosenberg
# Actors                [paulnewman, georgekennedy, j.d.cannon]
# Plot        A man refuses to conform to life in a rural pr...
# Name: 123, dtype: object
# Title                                             Gran Torino
# Genre                                                 [drama]
# Director                                        clinteastwood
# Actors            [clinteastwood, christophercarley, beevang]
# Plot        Disgruntled Korean War veteran Walt Kowalski s...
# Name: 124, dtype: object
# Title                                        The Big Lebowski
# Genre                                        [comedy,  crime]
# Director                                   joelcoen,ethancoen
# Actors              [jeffbridges, johngoodman, juliannemoore]
# Plot        "The Dude" Lebowski, mistaken for a millionair...
# Name: 125, dtype: object
# Title                                               The Thing
# Genre                             [horror,  mystery,  sci-fi]
# Director                                        johncarpenter
# Actors              [kurtrussell, wilfordbrimley, t.k.carter]
# Plot        A research facility in Antarctica comes across...
# Name: 126, dtype: object
# Title                                   It Happened One Night
# Genre                                      [comedy,  romance]
# Director                                           frankcapra
# Actors         [clarkgable, claudettecolbert, walterconnolly]
# Plot        A spoiled heiress running away from her family...
# Name: 127, dtype: object
# Title                                                   Fargo
# Genre                              [crime,  drama,  thriller]
# Director                                   joelcoen,ethancoen
# Actors           [williamh.macy, stevebuscemi, peterstormare]
# Plot        Jerry Lundegaard's inept crime falls apart due...
# Name: 128, dtype: object
# Title                                         The Sixth Sense
# Genre                            [drama,  mystery,  thriller]
# Director                                     m.nightshyamalan
# Actors           [brucewillis, haleyjoelosment, tonicollette]
# Plot        A boy who communicates with spirits that don't...
# Name: 129, dtype: object
# Title                                            Finding Nemo
# Genre                        [animation,  adventure,  comedy]
# Director                             andrewstanton,leeunkrich
# Actors         [albertbrooks, ellendegeneres, alexandergould]
# Plot        After his son is captured in the Great Barrier...
# Name: 130, dtype: object
# Title                                            Mary and Max
# Genre                            [animation,  comedy,  drama]
# Director                                           adamelliot
# Actors      [tonicollette, philipseymourhoffman, barryhump...
# Plot        A tale of friendship between two unlikely pen ...
# Name: 131, dtype: object
# Title                                  No Country for Old Men
# Genre                              [crime,  drama,  thriller]
# Director                                   ethancoen,joelcoen
# Actors              [tommyleejones, javierbardem, joshbrolin]
# Plot        Violence and mayhem ensue after a hunter stumb...
# Name: 132, dtype: object
# Title                                How to Train Your Dragon
# Genre                        [animation,  action,  adventure]
# Director                             deandeblois,chrissanders
# Actors             [jaybaruchel, gerardbutler, craigferguson]
# Plot        A hapless young Viking who aspires to hunt dra...
# Name: 133, dtype: object
# Title                                     There Will Be Blood
# Genre                                       [drama,  history]
# Director                                   paulthomasanderson
# Actors      [danielday-lewis, martinstringer, matthewbrade...
# Plot        A story of family, religion, hatred, oil and m...
# Name: 134, dtype: object
# Title                                           Into the Wild
# Genre                         [adventure,  biography,  drama]
# Director                                             seanpenn
# Actors            [emilehirsch, marciagayharden, williamhurt]
# Plot        After graduating from Emory University, top st...
# Name: 135, dtype: object
# Title                                       Kill Bill: Vol. 1
# Genre                             [action,  crime,  thriller]
# Director                                     quentintarantino
# Actors                     [umathurman, lucyliu, vivicaa.fox]
# Plot        The Bride wakens from a four-year coma. The ch...
# Name: 136, dtype: object
# Title                                               Gone Girl
# Genre                               [crime,  drama,  mystery]
# Director                                         davidfincher
# Actors          [benaffleck, rosamundpike, neilpatrickharris]
# Plot        With his wife's disappearance having become th...
# Name: 137, dtype: object
# Title                                           Life of Brian
# Genre                                                [comedy]
# Director                                           terryjones
# Actors              [grahamchapman, johncleese, terrygilliam]
# Plot        Brian is born on the original Christmas, in th...
# Name: 138, dtype: object
# Title                                                 Network
# Genre                                                 [drama]
# Director                                          sidneylumet
# Actors               [fayedunaway, williamholden, peterfinch]
# Plot        A television network cynically exploits a dera...
# Name: 139, dtype: object
# Title                                          Shutter Island
# Genre                                    [mystery,  thriller]
# Director                                       martinscorsese
# Actors           [leonardodicaprio, markruffalo, benkingsley]
# Plot        In 1954, a U.S. marshal investigates the disap...
# Name: 140, dtype: object
# Title                               In the Name of the Father
# Genre                                     [biography,  drama]
# Director                                          jimsheridan
# Actors           [alisoncrosbie, danielday-lewis, philipking]
# Plot        A man's coerced confession to an IRA bombing h...
# Name: 141, dtype: object
# Title                                                    Rush
# Genre                            [action,  biography,  drama]
# Director                                            ronhoward
# Actors             [chrishemsworth, danielbrühl, oliviawilde]
# Plot        The merciless 1970s rivalry between Formula On...
# Name: 142, dtype: object
# Title                                            Hotel Rwanda
# Genre                           [biography,  drama,  history]
# Director                                          terrygeorge
# ...
# Director                      jaredbush,byronhoward,richmoore
# Actors             [ginnifergoodwin, jasonbateman, idriselba]
# Plot        In a city of anthropomorphic animals, a rookie...
# Name: 202, dtype: object
# Title                          Guardians of the Galaxy Vol. 2
# Genre                           [action,  adventure,  sci-fi]
# Director                                            jamesgunn
# Actors                 [chrispratt, zoesaldana, davebautista]
# Plot        The Guardians must fight to keep their newfoun...
# Name: 203, dtype: object
# Title       Pirates of the Caribbean: The Curse of the Bla...
# Genre                          [action,  adventure,  fantasy]
# Director                                        goreverbinski
# Actors               [johnnydepp, geoffreyrush, orlandobloom]
# Plot        Blacksmith Will Turner teams up with eccentric...
# Name: 204, dtype: object
# Title                                           Before Sunset
# Genre                                       [drama,  romance]
# Director                                     richardlinklater
# Actors              [ethanhawke, juliedelpy, vernondobtcheff]
# Plot        Nine years after Jesse and Celine first met, t...
# Name: 205, dtype: object
# Title                                      The Imitation Game
# Genre                          [biography,  drama,  thriller]
# Director                                         mortentyldum
# Actors      [benedictcumberbatch, keiraknightley, matthewg...
# Plot        During World War II, mathematician Alan Turing...
# Name: 206, dtype: object
# Title                                      Young Frankenstein
# Genre                                                [comedy]
# Director                                            melbrooks
# Actors                 [genewilder, peterboyle, martyfeldman]
# Plot        An American grandson of the infamous scientist...
# Name: 207, dtype: object
# Title                                               Stalag 17
# Genre                                           [drama,  war]
# Director                                          billywilder
# Actors              [williamholden, dontaylor, ottopreminger]
# Plot        When two escaping American World War II prison...
# Name: 208, dtype: object
# Title                                                Dogville
# Genre                                         [crime,  drama]
# Director                                         larsvontrier
# Actors         [nicolekidman, harrietandersson, laurenbacall]
# Plot        A woman on the run from the mob is reluctantly...
# Name: 209, dtype: object
# Title                                      Dead Poets Society
# Genre                                        [comedy,  drama]
# Director                                            peterweir
# Actors         [robinwilliams, robertseanleonard, ethanhawke]
# Plot        English teacher John Keating inspires his stud...
# Name: 210, dtype: object
# Title                                               High Noon
# Genre                            [drama,  thriller,  western]
# Director                                        fredzinnemann
# Actors             [garycooper, thomasmitchell, lloydbridges]
# Plot        Marshal Will Kane, personally compelled to fac...
# Name: 211, dtype: object
# Title                                                Papillon
# Genre                             [biography,  crime,  drama]
# Director                                  franklinj.schaffner
# Actors              [stevemcqueen, dustinhoffman, victorjory]
# Plot        A man befriends a fellow criminal as the two o...
# Name: 212, dtype: object
# Title                                A Streetcar Named Desire
# Genre                                                 [drama]
# Director                                            eliakazan
# Actors                 [vivienleigh, marlonbrando, kimhunter]
# Plot        Disturbed Blanche DuBois moves in with her sis...
# Name: 213, dtype: object
# Title                                    Arsenic and Old Lace
# Genre                             [comedy,  crime,  thriller]
# Director                                           frankcapra
# Actors              [carygrant, priscillalane, raymondmassey]
# Plot        A drama critic learns on his wedding day that ...
# Name: 214, dtype: object
# Title                                                Sin City
# Genre                                      [crime,  thriller]
# Director         frankmiller,robertrodriguez,quentintarantino
# Actors                 [jessicaalba, devonaoki, alexisbledel]
# Plot        A film that explores the dark and miserable to...
# Name: 215, dtype: object
# Title                                             The Hustler
# Genre                                         [drama,  sport]
# Director                                         robertrossen
# Actors               [paulnewman, jackiegleason, piperlaurie]
# Plot        An up-and-coming pool player plays a long-time...
# Name: 216, dtype: object
# Title                                    A Night at the Opera
# Genre                              [comedy,  music,  musical]
# Director                               samwood,edmundgoulding
# Actors                    [grouchomarx, chicomarx, harpomarx]
# Plot        A sly business manager and two wacky friends o...
# Name: 217, dtype: object
# Title                                             The Killing
# Genre                             [crime,  drama,  film-noir]
# Director                                       stanleykubrick
# Actors             [sterlinghayden, coleengray, vinceedwards]
# Plot        Crooks plan and execute a daring race-track ro...
# Name: 218, dtype: object
# Title                                            The Avengers
# Genre                                       [action,  sci-fi]
# Director                                           josswhedon
# Actors             [robertdowneyjr., chrisevans, markruffalo]
# Plot        Earth's mightiest heroes must come together an...
# Name: 219, dtype: object
# Title                                               Notorious
# Genre                           [drama,  film-noir,  romance]
# Director                                      alfredhitchcock
# Actors                [carygrant, ingridbergman, clauderains]
# Plot        A woman is asked to spy on a group of Nazi fri...
# Name: 220, dtype: object
# Title                                                  Harvey
# Genre                              [comedy,  drama,  fantasy]
# Director                                          henrykoster
# Actors            [wallaceford, williamh.lynn, victoriahorne]
# Plot        Due to his insistence that he has an invisible...
# Name: 221, dtype: object
# Title                                             The Martian
# Genre                            [adventure,  drama,  sci-fi]
# Director                                          ridleyscott
# Actors              [mattdamon, jessicachastain, kristenwiig]
# Plot        An astronaut becomes stranded on Mars after hi...
# Name: 222, dtype: object
# Title                                            The Exorcist
# Genre                                                [horror]
# Director                                      williamfriedkin
# Actors                 [ellenburstyn, maxvonsydow, leej.cobb]
# Plot        When a teenage girl is possessed by a mysterio...
# Name: 223, dtype: object
# Title                                               Rio Bravo
# Genre                              [action,  drama,  western]
# Director                                          howardhawks
# Actors                   [johnwayne, deanmartin, rickynelson]
# Plot        A small-town sheriff in the American West enli...
# Name: 224, dtype: object
# Title                                  The Philadelphia Story
# Genre                                      [comedy,  romance]
# Director                                          georgecukor
# Actors            [carygrant, katharinehepburn, jamesstewart]
# Plot        When a rich woman's ex-husband and a tabloid-t...
# Name: 225, dtype: object
# Title                                                    Rope
# Genre                              [crime,  drama,  thriller]
# Director                                      alfredhitchcock
# Actors                [johndall, farleygranger, edithevanson]
# Plot        Two young men strangle their "inferior" classm...
# Name: 226, dtype: object
# Title                                           The Big Sleep
# Genre                           [crime,  film-noir,  mystery]
# Director                                          howardhawks
# Actors            [humphreybogart, laurenbacall, johnridgely]
# Plot        Private detective Philip Marlowe is hired by a...
# Name: 227, dtype: object
# Title                                    Pink Floyd: The Wall
# Genre                           [animation,  drama,  fantasy]
# Director                                           alanparker
# Actors       [bobgeldof, christinehargreaves, jameslaurenson]
# Plot        A confined but troubled rock star descends int...
# Name: 228, dtype: object
# Title                                       The King's Speech
# Genre                                     [biography,  drama]
# Director                                            tomhooper
# Actors          [colinfirth, helenabonhamcarter, derekjacobi]
# Plot        The story of King George VI of the United King...
# Name: 229, dtype: object
# Title                                       A Christmas Story
# Genre                                       [comedy,  family]
# Director                                             bobclark
# Actors       [melindadillon, darrenmcgavin, peterbillingsley]
# Plot        In the 1940s, a young boy named Ralphie attemp...
# Name: 230, dtype: object
# Title                                            The Graduate
# Genre                                        [comedy,  drama]
# Director                                          mikenichols
# Actors           [annebancroft, dustinhoffman, katharineross]
# Plot        A disillusioned college graduate finds himself...
# Name: 231, dtype: object
# Title                                                     JFK
# Genre                            [drama,  history,  thriller]
# Director                                          oliverstone
# Actors             [sallykirkland, anthonyramirez, raylepere]
# Plot        A New Orleans DA discovers there's more to the...
# Name: 232, dtype: object
# Title                                             Sling Blade
# Genre                                                 [drama]
# Director                                     billybobthornton
# Actors            [billybobthornton, dwightyoakam, j.t.walsh]
# Plot        Karl Childers, a simple man hospitalized since...
# Name: 233, dtype: object
# Title                                           Blood Diamond
# Genre                          [adventure,  drama,  thriller]
# Director                                          edwardzwick
# Actors      [leonardodicaprio, djimonhounsou, jenniferconn...
# Plot        A fisherman, a smuggler, and a syndicate of bu...
# Name: 234, dtype: object
# Title                                                Magnolia
# Genre                                                 [drama]
# Director                                   paulthomasanderson
# Actors               [pathealy, genevievezweig, markflanagan]
# Plot        An epic mosaic of interrelated characters in s...
# Name: 235, dtype: object
# Title                                                Rain Man
# Genre                                                 [drama]
# Director                                        barrylevinson
# Actors              [dustinhoffman, tomcruise, valeriagolino]
# Plot        Selfish yuppie Charlie Babbitt's father left a...
# Name: 236, dtype: object
# Title                                            The Revenant
# Genre                          [adventure,  drama,  thriller]
# Director                            alejandrogonzáleziñárritu
# Actors          [leonardodicaprio, tomhardy, domhnallgleeson]
# Plot        A frontiersman on a fur trading expedition in ...
# Name: 237, dtype: object
# Title                          The Nightmare Before Christmas
# Genre                          [animation,  family,  fantasy]
# Director                                          henryselick
# Actors          [dannyelfman, chrissarandon, catherineo'hara]
# Plot        Jack Skellington, king of Halloween Town, disc...
# Name: 238, dtype: object
# Title                                The Manchurian Candidate
# Genre                                      [drama,  thriller]
# Director                                    johnfrankenheimer
# Actors             [franksinatra, laurenceharvey, janetleigh]
# Plot        A former prisoner of war is brainwashed as an ...
# Name: 239, dtype: object
# Title                                                Deadpool
# Genre                           [action,  adventure,  comedy]
# Director                                            timmiller
# Actors                    [ryanreynolds, karansoni, edskrein]
# Plot        A fast-talking mercenary with a morbid sense o...
# Name: 240, dtype: object
# Title                                          The Wild Bunch
# Genre                          [action,  adventure,  western]
# Director                                         sampeckinpah
# Actors            [williamholden, ernestborgnine, robertryan]
# Plot        An aging group of outlaws look for one last bi...
# Name: 241, dtype: object
# Title                                                 Aladdin
# Genre                        [animation,  adventure,  comedy]
# Director                               ronclements,johnmusker
# Actors             [scottweinger, robinwilliams, lindalarkin]
# Plot        When a street urchin vies for the love of a be...
# Name: 242, dtype: object
# Title                                                Big Fish
# Genre                           [adventure,  drama,  fantasy]
# Director                                            timburton
# Actors              [ewanmcgregor, albertfinney, billycrudup]
# Plot        A frustrated son tries to determine the fact f...
# Name: 243, dtype: object
# Title                                                  Patton
# Genre                               [biography,  drama,  war]
# Director                                  franklinj.schaffner
# Actors              [georgec.scott, karlmalden, stephenyoung]
# Plot        The World War II phase of the career of the co...
# Name: 244, dtype: object
# Title                                        The Lost Weekend
# Genre                                     [drama,  film-noir]
# Director                                          billywilder
# Actors                  [raymilland, janewyman, phillipterry]
# Plot        The desperate life of a chronic alcoholic is f...
# Name: 245, dtype: object
# Title                                           Short Term 12
# Genre                                                 [drama]
# Director                                  destindanielcretton
# Actors       [brielarson, johngallagherjr., stephaniebeatriz]
# Plot        A 20-something supervising staff member of a r...
# Name: 246, dtype: object
# Title                                         His Girl Friday
# Genre                              [comedy,  drama,  romance]
# Director                                          howardhawks
# Actors             [carygrant, rosalindrussell, ralphbellamy]
# Plot        A newspaper editor uses every trick in the boo...
# Name: 247, dtype: object
# Title                                      The Straight Story
# Genre                                     [biography,  drama]
# Director                                           davidlynch
# Actors      [sissyspacek, janegallowayheitz, josepha.carpe...
# Plot        An old man makes a long journey by lawn-mover ...
# Name: 248, dtype: object
# Title                                     Slumdog Millionaire
# Genre                                                 [drama]
# Director                            dannyboyle,loveleentandan
# Actors                  [devpatel, saurabhshukla, anilkapoor]
# Plot        A Mumbai teen reflects on his upbringing in th...
# Name: 249, dtype: object

# %%
# initializing the new column
df['Key_words'] = ""

for index, row in df.iterrows():
    plot = row['Plot']
    
    # instantiating Rake, by default is uses english stopwords from NLTK
    # and discard all puntuation characters
    r = Rake()

    # extracting the words by passing the text
    r.extract_keywords_from_text(plot)

    # getting the dictionary whith key words and their scores
    key_words_dict_scores = r.get_word_degrees()
    
    # assigning the key words to the new column
    row['Key_words'] = list(key_words_dict_scores.keys())

# dropping the Plot column
df.drop(columns = ['Plot'], inplace = True)

# %%
df.set_index('Title', inplace = True)
df.head()
# Out:
#                                              Genre            Director  \
# Title
# The Shawshank Redemption           [crime,  drama]       frankdarabont
# The Godfather                      [crime,  drama]  francisfordcoppola
# The Godfather: Part II             [crime,  drama]  francisfordcoppola
# The Dark Knight           [action,  crime,  drama]    christophernolan
# 12 Angry Men                       [crime,  drama]         sidneylumet
#
#                                                               Actors  \
# Title
# The Shawshank Redemption      [timrobbins, morganfreeman, bobgunton]
# The Godfather                    [marlonbrando, alpacino, jamescaan]
# The Godfather: Part II         [alpacino, robertduvall, dianekeaton]
# The Dark Knight           [christianbale, heathledger, aaroneckhart]
# 12 Angry Men                  [martinbalsam, johnfiedler, leej.cobb]
#
#                                                                   Key_words
# Title
# The Shawshank Redemption  [eventual, redemption, acts, two, imprisoned, ...
# The Godfather             [reluctant, son, clandestine, empire, organize...
# The Godfather: Part II    [vito, corleone, expands, career, portrayed, s...
# The Dark Knight           [physical, tests, ability, fight, injustice, m...
# 12 Angry Men              [jury, holdout, attempts, miscarriage, prevent...

# %%
df['bag_of_words'] = ''
columns = df.columns
for index, row in df.iterrows():
    words = ''
    for col in columns:
        if col != 'Director':
            words = words + ' '.join(row[col])+ ' '
        else:
            words = words + row[col]+ ' '
    row['bag_of_words'] = words
    
df.drop(columns = [col for col in df.columns if col!= 'bag_of_words'], inplace = True)

# %%
df.head()
# Out:
#                                                                bag_of_words
# Title
# The Shawshank Redemption  crime  drama frankdarabont timrobbins morganfr...
# The Godfather             crime  drama francisfordcoppola marlonbrando a...
# The Godfather: Part II    crime  drama francisfordcoppola alpacino rober...
# The Dark Knight           action  crime  drama christophernolan christia...
# 12 Angry Men              crime  drama sidneylumet martinbalsam johnfied...

# %%
# instantiating and generating the count matrix
count = CountVectorizer()
count_matrix = count.fit_transform(df['bag_of_words'])

# creating a Series for the movie titles so they are associated to an ordered numerical
# list I will use later to match the indexes
indices = pd.Series(df.index)
indices[:5]
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                12 Angry Men
# Name: Title, dtype: object

# %%
count_matrix
# Out:
# <250x2961 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5342 stored elements in Compressed Sparse Row format>

# %%
# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)
cosine_sim
# Out:
# array([[1.        , 0.15789474, 0.13764944, ..., 0.05263158, 0.05263158,
#         0.05564149],
#        [0.15789474, 1.        , 0.36706517, ..., 0.05263158, 0.05263158,
#         0.05564149],
#        [0.13764944, 0.36706517, 1.        , ..., 0.04588315, 0.04588315,
#         0.04850713],
#        ...,
#        [0.05263158, 0.05263158, 0.04588315, ..., 1.        , 0.05263158,
#         0.05564149],
#        [0.05263158, 0.05263158, 0.04588315, ..., 0.05263158, 1.        ,
#         0.05564149],
#        [0.05564149, 0.05564149, 0.04850713, ..., 0.05564149, 0.05564149,
#         1.        ]])

# %%
# function that takes in movie title as input and returns the top 10 recommended movies
def recommendations(title, cosine_sim = cosine_sim):
    
    recommended_movies = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == title].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar movies
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # populating the list with the titles of the best 10 matching movies
    for i in top_10_indexes:
        recommended_movies.append(list(df.index)[i])
        
    return recommended_movies

# %%
list(df.index)[:5]
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Godfather: Part II',
#  'The Dark Knight',
#  '12 Angry Men']

# %% [markdown]
# Testing the Recommender

# %%
recommendations('Fargo')
# Out:
# ['No Country for Old Men',
#  'The Departed',
#  'Rope',
#  'The Godfather',
#  'Reservoir Dogs',
#  'The Godfather: Part II',
#  'On the Waterfront',
#  'Goodfellas',
#  'Arsenic and Old Lace',
#  'The Big Lebowski']
